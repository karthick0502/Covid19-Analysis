# %% [markdown]
# ### part1- creating and customizing our plots

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
con=(df['Country']=='India') & (df['LanguageWorkedWith'].str.contains('Python'))
con1=(df['Country']=='India') & (df['LanguageWorkedWith'].str.contains('Dart'))

# %%
df.loc[con].head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 21           22          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 225         227          I am a developer by profession      Yes  24.0
# 230         232  I am a student who is learning to code       No  20.0
# 232         234          I am a developer by profession      Yes  22.0
#
#     Age1stCode CompFreq  CompTotal  ConvertedComp Country  CurrencyDesc  ...  \
# 21          18  Monthly        NaN            NaN   India  Indian rupee  ...
# 62          17      NaN        NaN            NaN   India           NaN  ...
# 225         19   Yearly   840000.0        11728.0   India  Indian rupee  ...
# 230         12      NaN        NaN            NaN   India           NaN  ...
# 232         16      NaN        NaN            NaN   India           NaN  ...
#
#                      SurveyEase           SurveyLength Trans  \
# ...

# %%
x_data=df.loc[con].dropna(axis='index',how='any',subset=['Age','ConvertedComp'])
x_data1=df.loc[con1].dropna(axis='index',how='any',subset=['Age','ConvertedComp'])

# %%
x=x_data['Age'].sort_values()
x1=x_data1['Age'].sort_values()

# %%
x=x.astype(int)
x1=x1.astype(int)

# %%
x
# Out:
# 45409    19
# 8052     20
# 7329     20
# 23349    20
# 53983    21
#          ..
# 44292    44
# 17235    45
# 60727    45
# 28444    47
# 53984    51
# Name: Age, Length: 764, dtype: int32

# %%
df.loc[con,'ConvertedComp']
# Out:
# 21           NaN
# 62           NaN
# 225      11728.0
# 230          NaN
# 232          NaN
#           ...
# 64280        NaN
# 64303        NaN
# 64337        NaN
# 64381        NaN
# 64391        NaN
# Name: ConvertedComp, Length: 2670, dtype: float64

# %%
y=x_data['ConvertedComp'].sort_values()
y1=x_data1['ConvertedComp'].sort_values()

# %%
y=y.astype(int)
y1=y1.astype(int)

# %%
y
#y.unique().tolist()
# Out:
# 55464          0
# 20782          0
# 28444          0
# 60209          0
# 27289          0
#           ...
# 34637     670164
# 30459     686916
# 58170     753936
# 28428    1000000
# 8425     1000000
# Name: ConvertedComp, Length: 764, dtype: int32

# %%
plt.title('Ages and salaries who worked with Python & Dart in India')
plt.xlabel('ages')
plt.ylabel('salaries')
plt.plot(x,y) #plt.plot(x,y,label='Python')- to use instead of plot.legend()
plt.plot(x1,y1) #plt.plot(x1,y1,label='dart')- to use instead of plot.legend()
plt.legend(['Python','Dart']) # to show which colour represents which language

# %%
plt.plot(x,y,'g--',label='Python')
plt.plot(x1,y1,'r',label='dart')
plt.legend()

#we can get all colors and marks and line styles from formatted string in matplotlib official web
#https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(x,y,color='g',linestyle='--',marker='.',label='Python')
plt.plot(x1,y1,color='r',marker='o',label='dart')
plt.legend()

# %%
plt.plot(x,y,color='g',linestyle='--',label='Python')
plt.plot(x1,y1,color='r',linewidth=3,label='dart')
plt.legend()

# %%
plt.plot(x,y,'g--',label='Python')
plt.plot(x1,y1,'r',label='dart')
plt.legend()
plt.tight_layout() #to adjust the plot when we use laptop and system
plt.grid(True) # to show the grid lines into graph

# %%
plt.style.available#these are the styles was built in pyplot
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-dark')
plt.plot(x,y,'g--',label='Python')
plt.plot(x1,y1,'r',label='dart')
plt.legend()

# %%
#plt.xkcd()
plt.plot(x,y,'g--',label='Python')
plt.plot(x1,y1,'r',label='dart')
plt.legend()

# %%
plt.savefig('plot.png')

# %% [markdown]
# ### part2- bar charts and analyzing data from csv

# %%
plt.bar(x,y,label='Python') # we can use plt.bar to show the bar chart
plt.bar(x1,y1,label='dart')
plt.legend()
plt.tight_layout()
plt.grid(True)

#Here, the datas are overlapping

# %%
#to recify the overlap, we can use numpy
import numpy as np

# %%
x_index=np.arange(len(x))
x1_index=np.arange(len(x1))
width=0.25

# %%
plt.bar(x_index-width,y,width=width,label='Python') # we can use plt.bar to show the bar chart
plt.bar(x1_index,y1,width=width,label='dart')
plt.xticks(ticks=x_index,labels=x)
plt.legend()
plt.tight_layout()
plt.grid(True)

#we have lot of x values, thats why

#we can shift the python and dart values side by side when we can use numpy means we can offset those values

# %%
#plt.barh(x_index-width,y,width=width,label='Python') # we can use plt.bar to show the bar chart
#plt.barh(x1_index,y1,width=width,label='dart')
#plt.xticks(ticks=x_index,labels=x)
#plt.legend()
#plt.tight_layout()
#plt.grid(True)

# %%
df[['Respondent','LanguageWorkedWith']]
# Out:
#        Respondent                                 LanguageWorkedWith
# 0               1                             C#;HTML/CSS;JavaScript
# 1               2                                   JavaScript;Swift
# 2               3                           Objective-C;Python;Swift
# 3               4                                                NaN
# 4               5                                  HTML/CSS;Ruby;SQL
# ...           ...                                                ...
# 64456       64858                                                NaN
# 64457       64867  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458       64898                                                NaN
# 64459       64925                                           HTML/CSS
# 64460       65112                    C#;HTML/CSS;Java;JavaScript;SQL
#
# [64461 rows x 2 columns]

# %%
empty_removed_df=df.dropna(axis='index',how='any',subset=['Respondent','LanguageWorkedWith'])

# %%
empty_removed_df[['Respondent','LanguageWorkedWith']]
# Out:
#        Respondent                                 LanguageWorkedWith
# 0               1                             C#;HTML/CSS;JavaScript
# 1               2                                   JavaScript;Swift
# 2               3                           Objective-C;Python;Swift
# 4               5                                  HTML/CSS;Ruby;SQL
# 5               6                           HTML/CSS;Java;JavaScript
# ...           ...                                                ...
# 64447       63796                  C#;HTML/CSS;Java;JavaScript;Swift
# 64453       64330                                       C++;HTML/CSS
# 64457       64867  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64459       64925                                           HTML/CSS
# 64460       65112                    C#;HTML/CSS;Java;JavaScript;SQL
#
# [57378 rows x 2 columns]

# %%
from collections import Counter

# %%
language=Counter(['python','dart'])

# %%
language=language.update(['python','dart','c++'])

# %%
language

# %%
list_of_language=empty_removed_df['LanguageWorkedWith'].tolist()
list_of_language
# Out:
# ['C#;HTML/CSS;JavaScript',
#  'JavaScript;Swift',
#  'Objective-C;Python;Swift',
#  'HTML/CSS;Ruby;SQL',
#  'HTML/CSS;Java;JavaScript',
#  'C#;HTML/CSS;PHP',
#  'Python;SQL',
#  'HTML/CSS;JavaScript;PHP',
#  'HTML/CSS;Java;JavaScript;Python;SQL',
#  'C#;JavaScript;Swift',
#  'HTML/CSS;JavaScript',
#  'C;JavaScript;Python',
#  'HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL',
#  'Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript;Kotlin;R',
#  'C#;HTML/CSS;JavaScript;Python;SQL;VBA',
#  'Bash/Shell/PowerShell;HTML/CSS;Perl',
#  'Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Java;JavaScript;SQL',
#  'Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScript;Objective-C;Scala;SQL;Swift;TypeScript',
#  'Java;Python',
#  'Bash/Shell/PowerShell;C#;C++',
#  'Bash/Shell/PowerShell;Java;Kotlin;PHP;SQL',
#  'Bash/Shell/PowerShell;C',
#  'JavaScript;Python',
#  'Bash/Shell/PowerShell;C;C++;Java;Python;SQL',
#  'Python;R',
# ...

# %%
languages=Counter()

# %%
for language in list_of_language:
    languages.update(language.split(';'))

# %%
for language in list_of_language:
    a=language.split(';')
print(a)
# Out:
# ['C#', 'HTML/CSS', 'Java', 'JavaScript', 'SQL']

# %%
languages
# Out:
# Counter({'C#': 18041,
#          'HTML/CSS': 36181,
#          'JavaScript': 38822,
#          'Swift': 3397,
#          'Objective-C': 2340,
#          'Python': 25287,
#          'Ruby': 4046,
#          'SQL': 31413,
#          'Java': 23074,
#          'PHP': 15007,
#          'C': 12487,
#          'TypeScript': 14578,
#          'Bash/Shell/PowerShell': 18980,
#          'Kotlin': 4468,
#          'R': 3288,
#          'VBA': 3499,
#          'Perl': 1796,
#          'Scala': 2052,
#          'C++': 13707,
#          'Go': 5038,
#          'Haskell': 1222,
#          'Rust': 2929,
#          'Dart': 2280,
#          'Julia': 519,
#          'Assembly': 3553})

# %%
languages.most_common(10)
#for x in languages.most_common(10):
    #print(x)
# Out:
# [('JavaScript', 38822),
#  ('HTML/CSS', 36181),
#  ('SQL', 31413),
#  ('Python', 25287),
#  ('Java', 23074),
#  ('Bash/Shell/PowerShell', 18980),
#  ('C#', 18041),
#  ('PHP', 15007),
#  ('TypeScript', 14578),
#  ('C++', 13707)]

# %%
x_for_language=[]
y_for_popularity=[]
for x,y in languages.items(): #for x,y in sorted(languages.items()):
    x_for_language.append(x)
    y_for_popularity.append(y)

# %%
#x_for_language
x_for_language.reverse()

# %%
#y_for_popularity
y_for_popularity.reverse()

# %%
for x,y in languages.items():
    print(x,y)
# Out:
# C# 18041
# HTML/CSS 36181
# JavaScript 38822
# Swift 3397
# Objective-C 2340
# Python 25287
# Ruby 4046
# SQL 31413
# Java 23074
# PHP 15007
# C 12487
# TypeScript 14578
# Bash/Shell/PowerShell 18980
# Kotlin 4468
# R 3288
# VBA 3499
# Perl 1796
# Scala 2052
# C++ 13707
# Go 5038
# Haskell 1222
# Rust 2929
# Dart 2280
# Julia 519
# Assembly 3553

# %%
plt.title('popularity lanhuages on 2020 survey')
plt.xlabel('lanuages')
plt.ylabel('popularity')
plt.tight_layout()
plt.bar(x_for_language,y_for_popularity)
plt.grid(True)

# %%
plt.title('popularity lanhuages on 2020 survey')
plt.ylabel('lanuages')
plt.xlabel('popularity')
plt.tight_layout()
plt.barh(x_for_language,y_for_popularity,)
plt.grid(True)

# %%
languages.items()
# Out:
# dict_items([('C#', 18041), ('HTML/CSS', 36181), ('JavaScript', 38822), ('Swift', 3397), ('Objective-C', 2340), ('Python', 25287), ('Ruby', 4046), ('SQL', 31413), ('Java', 23074), ('PHP', 15007), ('C', 12487), ('TypeScript', 14578), ('Bash/Shell/PowerShell', 18980), ('Kotlin', 4468), ('R', 3288), ('VBA', 3499), ('Perl', 1796), ('Scala', 2052), ('C++', 13707), ('Go', 5038), ('Haskell', 1222), ('Rust', 2929), ('Dart', 2280), ('Julia', 519), ('Assembly', 3553)])

# %%
sorted(languages.items())
# Out:
# [('Assembly', 3553),
#  ('Bash/Shell/PowerShell', 18980),
#  ('C', 12487),
#  ('C#', 18041),
#  ('C++', 13707),
#  ('Dart', 2280),
#  ('Go', 5038),
#  ('HTML/CSS', 36181),
#  ('Haskell', 1222),
#  ('Java', 23074),
#  ('JavaScript', 38822),
#  ('Julia', 519),
#  ('Kotlin', 4468),
#  ('Objective-C', 2340),
#  ('PHP', 15007),
#  ('Perl', 1796),
#  ('Python', 25287),
#  ('R', 3288),
#  ('Ruby', 4046),
#  ('Rust', 2929),
#  ('SQL', 31413),
#  ('Scala', 2052),
#  ('Swift', 3397),
#  ('TypeScript', 14578),
#  ('VBA', 3499)]

# %% [markdown]
# ### part3- create a pie chart

# %%
plt.title('my basic pie chart')
plt.tight_layout()
slices=[70,30]
lab=['seventy','thirty']
plt.pie(slices,labels=lab)
# Out:
# ([<matplotlib.patches.Wedge at 0x25ccbbf7100>,
# ...
#  [Text(-0.6465637441936393, 0.8899187180267096, 'seventy'),
#   Text(0.6465637441936392, -0.8899187180267097, 'thirty')])

# %%
plt.title('my basic pie chart')
plt.tight_layout()
slices=[70,30,120,40]
lab=['seventy','thirty','hun-twenty','foutry']
color=['#fc4f30','yellow','#008fd5','green'] #we can use colors by their hex values
plt.pie(slices,labels=lab,colors=color,wedgeprops={'edgecolor':'black'}) #it is used to get what color wants in each edge lines
# Out:
# ([<matplotlib.patches.Wedge at 0x25ccbba0100>,
# ...
#  [Text(0.7294348884854752, 0.8233618545088073, 'seventy'),
#   Text(-0.5111955751796449, 0.9740015831181961, 'thirty'),
#   Text(-0.8233617520668647, -0.7294350041185184, 'hun-twenty'),
#   Text(0.974001690806738, -0.5111953699962625, 'foutry')])

# %%
labels=x_for_language[0:11]

# %%
slices=y_for_popularity[0:11]

# %%
plt.title('my basic pie chart')
plt.tight_layout()
plt.pie(slices,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x25ccbb59400>,
# ...
#  [Text(1.0572003096716627, 0.30385441453126927, 'Assembly'),
#   Text(0.9074820857789304, 0.6216721515319166, 'Julia'),
#   Text(0.7495575561715037, 0.8050860016086501, 'Dart'),
#   Text(0.36619429080633353, 1.0372568348200202, 'Rust'),
#   Text(0.013646554372225835, 1.0999153474489598, 'Haskell'),
#   Text(-0.5086353602923109, 0.975341002039959, 'Go'),
#   Text(-1.0188795514947993, -0.41458950727889504, 'C++'),
#   Text(0.06265535239262209, -1.0982141443345903, 'Scala'),
#   Text(0.3876026037487916, -1.029448503601398, 'Perl'),
#   Text(0.7714040304020451, -0.7841784375252108, 'VBA'),
#   Text(1.0633122280500422, -0.28172168123744956, 'R')])

# %%
x_for_language.index('C++')
# Out:
# 6

# %%
y_for_popularity[6]
# Out:
# 13707

# %%
plt.title('my basic pie chart')
plt.tight_layout()
explode=[0,0,0,0,0.1,0,0.2,0,0,0.3,0] #explode can use to seperate the slices
plt.pie(slices,labels=labels,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x25ccbb8cf70>,
# ...
#  [Text(1.0572003096716627, 0.30385441453126927, 'Assembly'),
#   Text(0.9074820857789304, 0.6216721515319166, 'Julia'),
#   Text(0.7495575561715037, 0.8050860016086501, 'Dart'),
#   Text(0.36619429080633353, 1.0372568348200202, 'Rust'),
#   Text(0.014887150224246366, 1.1999076517625016, 'Haskell'),
#   Text(-0.5086353602923109, 0.975341002039959, 'Go'),
#   Text(-1.204130379039308, -0.4899694176932396, 'C++'),
#   Text(0.06265535239262209, -1.0982141443345903, 'Scala'),
#   Text(0.3876026037487916, -1.029448503601398, 'Perl'),
#   Text(0.981786947784421, -0.9980452841229955, 'VBA'),
#   Text(1.0633122280500422, -0.28172168123744956, 'R')])

# %%
plt.title('my basic pie chart')
plt.tight_layout()
explode=[0,0,0,0,0.1,0,0.2,0,0,0.3,0] #explode can use to seperate the slices
plt.pie(slices,labels=labels,explode=explode,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x25cb3f2c400>,
# ...
#  [Text(1.0572003096716627, 0.30385441453126927, 'Assembly'),
#   Text(0.9074820857789304, 0.6216721515319166, 'Julia'),
#   Text(0.7495575561715037, 0.8050860016086501, 'Dart'),
#   Text(0.36619429080633353, 1.0372568348200202, 'Rust'),
#   Text(0.014887150224246366, 1.1999076517625016, 'Haskell'),
#   Text(-0.5086353602923109, 0.975341002039959, 'Go'),
#   Text(-1.204130379039308, -0.4899694176932396, 'C++'),
#   Text(0.06265535239262209, -1.0982141443345903, 'Scala'),
#   Text(0.3876026037487916, -1.029448503601398, 'Perl'),
#   Text(0.981786947784421, -0.9980452841229955, 'VBA'),
#   Text(1.0633122280500422, -0.28172168123744956, 'R')])

# %%
plt.title('my basic pie chart')
plt.tight_layout()
explode=[0,0,0,0,0.1,0,0.2,0,0,0.3,0] #explode can use to seperate the slices
plt.pie(slices,labels=labels,explode=explode,shadow=True,wedgeprops={'edgecolor':'black'},startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x25cc82e9610>,
# ...
#  [Text(-0.30385441453126916, 1.057200309671663, 'Assembly'),
#   Text(-0.6216721515319165, 0.9074820857789304, 'Julia'),
#   Text(-0.80508600160865, 0.7495575561715038, 'Dart'),
#   Text(-1.0372568348200202, 0.3661942908063338, 'Rust'),
#   Text(-1.1999076517625016, 0.014887150224246175, 'Haskell'),
#   Text(-0.975341002039959, -0.5086353602923108, 'Go'),
#   Text(0.48996941769324004, -1.2041303790393079, 'C++'),
#   Text(1.0982141443345903, 0.06265535239262202, 'Scala'),
#   Text(1.029448503601398, 0.38760260374879146, 'Perl'),
#   Text(0.9980452841229955, 0.9817869477844209, 'VBA'),
#   Text(0.2817216812374496, 1.0633122280500422, 'R')])

# %%
plt.title('my basic pie chart')
plt.tight_layout()
explode=[0,0,0,0,0.1,0,0.2,0,0,0.3,0] #explode can use to seperate the slices
plt.pie(slices,labels=labels,explode=explode,shadow=True,wedgeprops={'edgecolor':'black'},startangle=90,autopct='%0.3f')
#autopct '%1.1f%%'can be use the percentage values for each labels depends on the wedges
# Out:
# ([<matplotlib.patches.Wedge at 0x25cc79f5610>,
# ...
#  [Text(-0.30385441453126916, 1.057200309671663, 'Assembly'),
#   Text(-0.6216721515319165, 0.9074820857789304, 'Julia'),
#   Text(-0.80508600160865, 0.7495575561715038, 'Dart'),
#   Text(-1.0372568348200202, 0.3661942908063338, 'Rust'),
#   Text(-1.1999076517625016, 0.014887150224246175, 'Haskell'),
#   Text(-0.975341002039959, -0.5086353602923108, 'Go'),
#   Text(0.48996941769324004, -1.2041303790393079, 'C++'),
#   Text(1.0982141443345903, 0.06265535239262202, 'Scala'),
#   Text(1.029448503601398, 0.38760260374879146, 'Perl'),
#   Text(0.9980452841229955, 0.9817869477844209, 'VBA'),
#   Text(0.2817216812374496, 1.0633122280500422, 'R')],
#  [Text(-0.16573877156251043, 0.5766547143663615, '8.909'),
#   Text(-0.33909390083559077, 0.4949902286066893, '1.301'),
#   Text(-0.4391378190592636, 0.40884957609354744, '5.717'),
#   Text(-0.5657764553563746, 0.19974234043981842, '7.344'),
# ...

# %% [markdown]
# ### part4- stack plots

# %%
#if three members are in team and play a video game, we have to use stack plot to find 
#which players get how many points at each min and also find the total points of each players and total points of team

min=[1,2,3,4,5,6,7,8,9] #it is used for x value

player1=[1,1,1,2,3,5,4,1,6] #these are all the y values
player2=[1,2,1,2,1,1,6,1,1]
player3=[1,2,2,1,1,5,1,5,6]

# %%
plt.grid(True)
plt.title('basic stack plots')
plt.tight_layout()
labe=['player1','player2','player3']
plt.stackplot(min,player1,player2,player3,labels=labe)
plt.legend()

# %%
plt.grid(True)
plt.title('basic stack plots')
plt.tight_layout()
labe=['player1','player2','player3']
plt.stackplot(min,player1,player2,player3,labels=labe)
plt.legend(loc='upper left')

# %%
plt.grid(True)
plt.title('basic stack plots')
plt.tight_layout()
labe=['player1','player2','player3']
colo=['#6d904f','#fc4f30','#008fd5']
plt.stackplot(min,player1,player2,player3,labels=labe,colors=colo)
plt.legend(loc='upper left') #plt.legend((0.07,0.05))- we can get info from googel matplotlib legend (here, 7% from left and 5% from bottom)

# %% [markdown]
# ### part5- Filling area on line plots

# %%
#in line plot- we can use plt.fill_between() mehthod to fill the the plots where exact condition matches

# %%
cdf=pd.read_csv('k:\project work\COVID-19_Daily_Cases__Deaths__and_Hospitalizations.csv')

# %%
cdf=cdf.dropna(axis='index',how='any')

# %%
cdf
# Out:
#            Date  Cases - Total  Deaths - Total  Cases - Age 0-17  \
# 0    03/01/2020              0               0                 0
# 1    03/02/2020              0               0                 0
# 2    03/03/2020              0               0                 0
# 3    03/04/2020              0               0                 0
# 4    03/05/2020              1               0                 0
# ..          ...            ...             ...               ...
# 164  06/04/2020            322              15                27
# 165  07/29/2020            440               3                56
# 166  06/15/2020            234              20                36
# 167  04/16/2020            682              31                 8
# 168  04/22/2020           1061              45                33
#
#      Cases - Age 18-29  Cases - Age 30-39  Cases - Age 40-49  \
# 0                    0                  0                  0
# ...

# %%
filt=(cdf['Date']>='03/01/2020') & (cdf['Date']<='03/30/2020')

# %%
x=cdf.loc[filt,'Date']
y=cdf.loc[filt,'Cases - Age 18-29']
y1=cdf.loc[filt,'Cases - Age 30-39']

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y)
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y1,alpha=0.25) #aplha can use the fil with dim shades so that we can easily look up on those two edges
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
ym=cdf.loc[filt,'Cases - Age 18-29'].median()
#y1m=cdf.loc[filt,'Cases - Age 30-39']

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,ym,alpha=0.25) #when we want to fill the shades below and above median value then we can give that median value in third parameter 
                                   #in fill_between()
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,ym,where=(y<ym),interpolate=True,alpha=0.25) #mark the shades only condition applied in where clause
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,ym,where=(y<ym),interpolate=True,alpha=0.25) #mark the shades only condition applied in where clause
plt.fill_between(x,y,ym,where=(y>=ym),interpolate=True,alpha=0.25) #we can apply diff condition using multiple fill_between()
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,ym,where=(y<ym),interpolate=True,color='green',alpha=0.25) #mark the shades only condition applied in where clause
plt.fill_between(x,y,ym,where=(y>=ym),interpolate=True,color='red',alpha=0.25) #we can apply diff condition using multiple fill_between()
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,y1,where=(y<y1),interpolate=True,color='green',alpha=0.25) #mark the shades only condition applied in where clause
plt.fill_between(x,y,y1,where=(y>=y1),interpolate=True,color='red',alpha=0.25) #we can apply diff condition using multiple fill_between()
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %%
plt.plot(x,y,label='ages 18-29')
plt.plot(x,y1,label='ages 30-39')
plt.fill_between(x,y,y1,where=(y<y1),interpolate=True,color='green',alpha=0.25,label='below 18-29 when compare than 30-39') 
plt.fill_between(x,y,y1,where=(y>=y1),interpolate=True,color='red',alpha=0.25,label='above 18-29 when compare than 30-39') 
plt.legend()
plt.title('covid cases graph')
plt.xlabel('dates')
plt.ylabel('covid cases age 18-29')
plt.tight_layout()

# %% [markdown]
# ### part6- Histograms

# %%
#bins- it is seperate the full x columns and provides the how many of them repondant for each bins
#ex- if bins=5, then it is seperates five division and show us the result

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
columns=df.columns

# %%
df=df.dropna(axis='index',how='any',subset=columns)

# %%
filt=(df['Country']=='India')

# %%
data=df.loc[filt,['Age','Respondent']].astype(int)

# %%
ages=data['Age']
res_id=data['Respondent']

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
plt.hist(ages)

plt.tight_layout()
plt.show()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
plt.hist(ages,bins=3) #when we use bins it will seperate it as 3

plt.tight_layout()
plt.show()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
plt.hist(ages,bins=3,edgecolor='black') #edgecolor can be used to see the differentiate of each edges
plt.grid(True)
plt.tight_layout()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
bins=[20,30,40,50,60] #we can pass list of values into bins
plt.hist(ages,bins=bins,edgecolor='black') 
plt.grid(True)
plt.tight_layout()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
bins=[30,40,50] #we can pass list of values into bins. Here, we have three values and two bins into graph like (20-30,30-40)
plt.hist(ages,bins=bins,edgecolor='black') 
plt.grid(True)
plt.tight_layout()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
bins=[15,20,25,30,35,40,45,50] 
plt.hist(ages,bins=bins,edgecolor='black') 
plt.grid(True)
plt.tight_layout()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
bins=[15,20,25,30,35,40,45,50] 
plt.hist(ages,bins=bins,edgecolor='black',log=True) #to see the result in logrethemic value
plt.grid(True)
plt.tight_layout()

# %%
median=ages.median()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
color='#fc4f30'
bins=[15,20,25,30,35,40,45,50] 
plt.hist(ages,bins=bins,edgecolor='black')
plt.axvline(median,color=color,label='median of ages') #axvline is called as axis vertical line to draw the line of median ages
plt.grid(True)
plt.tight_layout()
plt.legend()

# %%
plt.title('simple histograms')
plt.xlabel('ages')
plt.ylabel('respondant-id')
color='#fc4f30'
bins=[15,20,25,30,35,40,45,50] 
plt.hist(ages,bins=bins,edgecolor='black')
plt.axvline(median,color=color,label='median of ages',linewidth=5) #we can change the thick of line
plt.grid(True)
plt.tight_layout()
plt.legend()

# %% [markdown]
# ### part7- scatter plots

# %%
import random as r

# %%
r.sample(range(10,25),9)
# Out:
# [14, 10, 23, 11, 22, 21, 18, 13, 24]

# %%
x=[]
for i in range(20):
    x.append(r.randint(1,9))

# %%
x
# Out:
# [9, 1, 4, 6, 1, 5, 5, 4, 5, 2, 7, 8, 2, 6, 3, 5, 3, 8, 4, 7]

# %%
y=[]
for i in range(20):
    y.append(r.randint(1,9))

# %%
y
# Out:
# [5, 3, 2, 4, 8, 4, 7, 2, 1, 6, 3, 7, 5, 9, 4, 1, 4, 3, 6, 6]

# %%
plt.style.use('seaborn')

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,s=100,c='green',marker='X') #s arguments we can use the change the size of dots
#c is the arguments to change the color
#marker is the argument that we can use change the mark value from dot to another

# %%
plt.scatter(x,y,c='green',edgecolor='black',linewidth=1,alpha=1)

# %%
color=[]
for i in range(20):
    color.append(r.randint(1,9))

# %%
color
# Out:
# [3, 7, 8, 2, 7, 6, 6, 3, 4, 7, 8, 1, 7, 6, 4, 2, 4, 5, 5, 5]

# %%
plt.scatter(x,y,c=color,edgecolor='black',linewidth=1,alpha=1)

# %%
#color map is used to mark the color which we want.. .we can separately study about color map
plt.scatter(x,y,c=color,cmap='Greens',edgecolor='black',linewidth=1,alpha=1)

# %%
plt.scatter(x,y,c=color,cmap='Greens',edgecolor='black',linewidth=1,alpha=1)
plt.colorbar(label='satisfaction')

# %%
size=[]
for i in range(20):
     size.append(r.randint(100,200))

# %%
size
# Out:
# [199,
#  190,
#  132,
#  163,
#  134,
#  107,
#  142,
#  131,
#  180,
#  138,
#  132,
#  106,
#  123,
#  187,
#  118,
#  134,
#  143,
#  104,
#  124,
#  104]

# %%
plt.scatter(x,y,s=size,c=color,cmap='Greens',edgecolor='black',linewidth=1,alpha=1)
plt.colorbar(label='satisfaction')

# %%
cdf
# Out:
#            Date  Cases - Total  Deaths - Total  Cases - Age 0-17  \
# 0    03/01/2020              0               0                 0
# 1    03/02/2020              0               0                 0
# 2    03/03/2020              0               0                 0
# 3    03/04/2020              0               0                 0
# 4    03/05/2020              1               0                 0
# ..          ...            ...             ...               ...
# 164  06/04/2020            322              15                27
# 165  07/29/2020            440               3                56
# 166  06/15/2020            234              20                36
# 167  04/16/2020            682              31                 8
# 168  04/22/2020           1061              45                33
#
#      Cases - Age 18-29  Cases - Age 30-39  Cases - Age 40-49  \
# 0                    0                  0                  0
# ...

# %%
filt=(cdf['Date']>='03/01/2020') & (cdf['Date']<='03/30/2020')

# %%
x=cdf.loc[filt,'Date']

# %%
y=cdf.loc[filt,'Cases - Total']

# %%
death=cdf.loc[filt,'Deaths - Total']

# %%
plt.scatter(x,y,c=death,edgecolor='black',cmap='summer',linewidth=1,alpha=0.5)
plt.colorbar(label='total deaths')
plt.xlabel('dates')
plt.ylabel('total cases')
# Out:
# Text(0, 0.5, 'total cases')

# %% [markdown]
# ### part8- time series data and plotting date

# %%
from datetime import datetime,timedelta
from matplotlib import dates as mpl_dates

# %%
x=[]
for i in range(1,10):
    x.append(datetime(2020,5,i))

# %%
x
# Out:
# [datetime.datetime(2020, 5, 1, 0, 0),
#  datetime.datetime(2020, 5, 2, 0, 0),
#  datetime.datetime(2020, 5, 3, 0, 0),
#  datetime.datetime(2020, 5, 4, 0, 0),
#  datetime.datetime(2020, 5, 5, 0, 0),
#  datetime.datetime(2020, 5, 6, 0, 0),
#  datetime.datetime(2020, 5, 7, 0, 0),
#  datetime.datetime(2020, 5, 8, 0, 0),
#  datetime.datetime(2020, 5, 9, 0, 0)]

# %%
y=[]
for i in range(1,10):
    y.append(r.randint(1,9))

# %%
y
# Out:
# [5, 5, 3, 7, 5, 2, 3, 5, 4]

# %%
plt.style.use('seaborn')
plt.plot_date(x,y)

# %%
plt.style.use('seaborn')
plt.plot_date(x,y,linestyle='solid') #we can use the linestyle parameter to connect the dots

# %%
#we can use the marker keyword to hide the dots
plt.plot_date(x,y,linestyle='solid',marker=None)

# %%
plt.style.use('seaborn')
plt.plot_date(x,y,linestyle='solid')
plt.gcf().autofmt_xdate() #gcf means get current figure method that can use the modify the date and get the current figure 
#and run the auto format method
#then we can use autofmt_xdate() into figure method

# %%
plt.style.use('seaborn')
plt.plot_date(x,y,linestyle='solid')
plt.gcf().autofmt_xdate()

date_format=mpl_dates.DateFormatter('%b %d %Y') #DateFormatter() can be use to change the formate of dates
plt.gca().xaxis.set_major_formatter(date_format) #gca() means get current axis method can be use to access the particular axis

#Here we are using xaxis by using keyword as 'xaxis' and set the date formate by using the keyword like 'set_major_formatter'

# %%
filt=(cdf['Date']>='04/01/2020') & (cdf['Date']<='04/30/2020')
#dates=cdf.loc[filt,'Date']
#deaths=cdf.loc[filt,'Deaths - Total']

# %%
df=cdf.loc[filt,['Date','Deaths - Total']].sort_values(by='Date')

# %%
dates=df['Date']
deaths=df['Deaths - Total']

# %%
plt.style.use('seaborn')
plt.plot_date(dates,deaths,linestyle='solid')
plt.gcf().autofmt_xdate()
plt.xlabel('dates')
plt.ylabel('deaths')

#here all dates are considered as a strings
# Out:
# Text(0, 0.5, 'deaths')

# %%
#when date is un ordered collection and it is type as object then we can change as datetime method by use following methods
cdf['Date']=pd.to_datetime(cdf['Date'])

# %%
cdf['Date']
# Out:
# 0     2020-03-01
# 1     2020-03-02
# 2     2020-03-03
# 3     2020-03-04
# 4     2020-03-05
#          ...
# 164   2020-06-04
# 165   2020-07-29
# 166   2020-06-15
# 167   2020-04-16
# 168   2020-04-22
# Name: Date, Length: 163, dtype: datetime64[ns]

# %% [markdown]
# ### part9- plotting real time

# %% [markdown]
# ### use my pycharm to see output

# %%
from itertools import count

#count() can be use to generate a unique sequence number at each time

# %%
index=count()
x=[]
y=[]

# %%
def animate(i):
    x.append(next(index))
    y.append(r.randint(1,5))
    
#we can plot when each time function runs so that we should use funcanimation method in matplotlib

#at the specific interval we can plot with data of what the animate function have

# %%
#to import the animation method
from matplotlib.animation import FuncAnimation

# %%
def animate(i):
    x.append(next(index))
    y.append(r.randint(1,5))
    plt.plot(x,y)

# %%
ani=FuncAnimation(plt.gcf(),animate,interval=1000) #plt.gcf()-get current figure can be use to get the reference to current figure
plt.style.use('seaborn')
plt.show()
#interval can be use that how often we want to make a plot(interval is basically being as milli sec) ex: 1000 is 1sec

# %%
# these all code is available in my pycharm projects

# %% [markdown]
# ### part 10- sub plots

# %%
#figures- is the container that holding our plots(figuures can have mutiple plots)
#axis- is the current plots
#plt.gcf()- this can be use to get current figure
#plt.gca()- to get current axis

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
filt=(df['Country']=='India')

# %%
main_df=df.loc[filt,['Age','ConvertedComp','LanguageWorkedWith']]

# %%
len(main_df)
# Out:
# 8403

# %%
main_df=main_df.dropna(axis='index',how='any')

# %%
len(main_df)
# Out:
# 2165

# %%
main_df[['Age','ConvertedComp']]=main_df[['Age','ConvertedComp']].astype(int)

# %%
main_df=main_df[(main_df['Age']>=20) & (main_df['Age']<=35)]

# %%
main_df
# Out:
#        Age  ConvertedComp                                 LanguageWorkedWith
# 225     24          11728                             Java;JavaScript;Python
# 320     24           4188             HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 412     24          23735                                     Python;R;Scala
# 472     25          10471                       HTML/CSS;Java;JavaScript;SQL
# 595     31          34206                                  Go;Rust;Scala;SQL
# ...    ...            ...                                                ...
# 61460   24          25131  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 61463   26           4189                                                 C#
# 61529   32          11169                                C#;HTML/CSS;SQL;VBA
# 61647   27          11169    C;C++;HTML/CSS;Java;JavaScript;PHP;Python;R;SQL
# 61665   24          12566            HTML/CSS;Java;JavaScript;SQL;TypeScript
#
# [2047 rows x 3 columns]

# %%
main_df=main_df[(main_df['Age']>=20) & (main_df['Age']<=30)]

# %%
main_df=main_df.sort_values(by='Age')

# %%
main_df
# Out:
#        Age  ConvertedComp                        LanguageWorkedWith
# 23349   20           8376          HTML/CSS;Java;Kotlin;Python;Rust
# 8052    20          12566   C++;HTML/CSS;Java;JavaScript;Python;SQL
# 5916    20           2508       C;C#;C++;Dart;HTML/CSS;Java;PHP;SQL
# 9460    20           2508                          C;C++;JavaScript
# 29165   20           1260                   HTML/CSS;JavaScript;PHP
# ...    ...            ...                                       ...
# 24085   30         211104  HTML/CSS;JavaScript;PHP;Scala;TypeScript
# 6097    30          11728     C#;HTML/CSS;JavaScript;SQL;TypeScript
# 53782   30           2340                                      Java
# 8908    30           5196                       HTML/CSS;JavaScript
# 31422   30          18096                  HTML/CSS;Java;Kotlin;SQL
#
# [1784 rows x 3 columns]

# %%
main_df.agg(['median','mean'])
# Out:
#               Age  ConvertedComp
# median  25.000000    9075.000000
# mean    25.636771   20200.471973

# %%
python_fil=main_df['LanguageWorkedWith'].str.contains('Python')
dart_fil=main_df['LanguageWorkedWith'].str.contains('Dart')
sql_fil=main_df['LanguageWorkedWith'].str.contains('SQL')

# %%
xp= main_df.loc[python_fil,'Age']
xd=main_df.loc[dart_fil,'Age']
xs=main_df.loc[sql_fil,'Age']

# %%
yp=main_df.loc[python_fil,'ConvertedComp']
yd=main_df.loc[dart_fil,'ConvertedComp']
ys=main_df.loc[sql_fil,'ConvertedComp']

# %%
plt.style.use('seaborn')

# %%
plt.plot(xp,yp,label='Python')
plt.plot(xd,yd,label='Dart')
plt.plot(xs,ys,label='SQL')
plt.legend()

# %%
#figures- is the container that holding our plots(figuures can have mutiple plots)
#axis- is the current plots
#plt.gcf()- this can be use to get current figure
#plt.gca()- to get current axis

# %%
#we can use subplots to differentiate the   plots. we can use figures and axis instead of using plot object via plt.subplots()

# %%
fig,ax=plt.subplots()
ax.plot(xp,yp,label='Python')
ax.plot(xd,yd,label='Dart')
ax.plot(xs,ys,label='SQL')
ax.legend()

#we are getting same plots above we got but we can access the based on axis(number of rows and columns)

# %%
fig,ax=plt.subplots()
print(ax)

#it will return one object (by default one row and one column)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
fig,ax=plt.subplots(nrows=2,ncols=1)
print(ax)

#here it will return two  object
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
fig,ax=plt.subplots(nrows=2,ncols=2)
print(ax)
# Out:
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]

# %%
fig,ax=plt.subplots(nrows=1,ncols=2)
print(ax)
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %% [markdown]
# ## here rows for x axis represent and columns for y axis represent

# %% [markdown]
# ### we can use unpacking method to split the axisplots

# %%
fig,ax=plt.subplots(nrows=2,ncols=1)
print(ax)

#here, tow axessubplot are existing within single list
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1)
print(ax1)
print(ax2)

#here, two axessubplots are seperately existing
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1)

ax1.plot(xs,ys,label='SQL',color='red') #in first axis we are plotting sql alone only
ax2.plot(xp,yp,label='Python') #in second axis we are plotting python and dart together
ax2.plot(xd,yd,label='Dart')


ax1.legend()
ax1.set_title('salaries of each lanugage in india')
#ax1.set_xlabel('ages')
ax1.set_ylabel('salaries')


ax2.legend()
#ax2.set_title('salary in Python & Dart')
ax2.set_xlabel('ages')
ax2.set_ylabel('salaries')
# Out:
# Text(0, 0.5, 'salaries')

# %%
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1,sharex=True) #sharex can be use to sharing the x axis values(it can applicable in y axis)

ax1.plot(xs,ys,label='SQL',color='red') 
ax2.plot(xp,yp,label='Python') 
ax2.plot(xd,yd,label='Dart')


ax1.legend()
ax1.set_title('salaries of each lanugage in india')
#ax1.set_xlabel('ages')
ax1.set_ylabel('salaries')


ax2.legend()
#ax2.set_title('salary in Python & Dart')
ax2.set_xlabel('ages')
ax2.set_ylabel('salaries')
# Out:
# Text(0, 0.5, 'salaries')

# %%
fig1,ax1=plt.subplots()
fig2,ax2=plt.subplots() #we can seperate the figures as well

ax1.plot(xs,ys,label='SQL',color='red') 
ax2.plot(xp,yp,label='Python') 
ax2.plot(xd,yd,label='Dart')


ax1.legend()
ax1.set_title('salaries of each lanugage in india')
ax1.set_xlabel('ages')
ax1.set_ylabel('salaries')


ax2.legend()
ax2.set_title('salary in Python & Dart')
ax2.set_xlabel('ages')
ax2.set_ylabel('salaries')
# Out:
# Text(0, 0.5, 'salaries')

# %%
#we can save the figures by using savefig()

# %%
fig1.savefig('fig1')
fig2.savefig('fig2')
